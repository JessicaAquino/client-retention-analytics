# %% [markdown]
# # Crear la clase  Target
#
# ## Ejercicio 1
#
# Cree el archivo competencia_01.csv, usando el competencia_01_crudo.csv con una variable adicional llamada clase_ternaria, que contenga las categorías **CONTINUA, BAJA+1 y BAJA+2**
#
# Ayudita
# Para practicar el muy útil y necesario lenguaje **SQL**, vamos a utilizar una base de datos **OLAP** llamada **DuckDB**.
#
# La documentación la puede encontrar [aquí](https://duckdb.org/docs/archive/0.8.1/sql/introduction) Procedemos a instalarla, esto se debe ejecutar una sola vez

# %%
# %pip install duckdb jupysql duckdb-engine pandas
# Out:
# Requirement already satisfied: duckdb in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.3.2)
# Requirement already satisfied: jupysql in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.11.1)
# Requirement already satisfied: duckdb-engine in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.17.0)
# Requirement already satisfied: pandas in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.3.2)
# Requirement already satisfied: prettytable>=3.12.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (3.16.0)
# Requirement already satisfied: sqlalchemy in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (2.0.43)
# Requirement already satisfied: sqlparse in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (0.5.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: jinja2 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (27.10.0)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jupysql) (0.2.27)
# Requirement already satisfied: packaging>=21 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from duckdb-engine) (24.2)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyyaml in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ploomber-core>=0.2.7->jupysql) (6.0.2)
# Requirement already satisfied: posthog>=3.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ploomber-core>=0.2.7->jupysql) (6.7.0)
# Requirement already satisfied: wcwidth in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prettytable>=3.12.0->jupysql) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: greenlet>=1 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy->jupysql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy->jupysql) (4.13.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->jupysql) (3.0.2)
# Requirement already satisfied: requests<3.0,>=2.7 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.32.5)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jessa\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0,>=2.7->posthog>=3.0->ploomber-core>=0.2.7->jupysql) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: C:\Users\jessa\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# Configuramos el entorno de ejecución. Si ya tiene todo instalado, solo necesita ejecutar esta celda para empezar a usar **duckdb**

# %%
import duckdb
import pandas as pd

# %load_ext sql
# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb://
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# Y ya podemos usar **SQL** dentro de una notebook!

# %%
# %%sql
# select 'hola mundo'
# Out:
#   'hola mundo'
# 0   hola mundo

# %% [markdown]
# Para cargar el archivo `.csv` a una tabla pasando su ubicación a través de la variable `dataset_path`:

# %%
dataset_path = '../datasets/'
dataset_file = 'competencia_01_crudo.csv'

# %%
# %%sql
# create or replace table competencia_01_crudo as
# select
#     *
# from read_csv_auto("{{dataset_path + dataset_file}}")
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %% [markdown]
# Hagamos unas queries básicas para comprobar que todo esta funcionando bien.

# %%
# %sql select * from competencia_01_crudo limit 5
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0          249221323    202101               1            0         0
# 1          249227600    202101               1            0         0
# 2          249234235    202101               1            0         0
# 3          249244449    202101               1            0         0
# 4          249244739    202101               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            46                  93        3070.24              15691.10
# 1            42                 278         496.21              15321.80
# 2            54                  17         806.56              10549.80
# 3            61                 290       27485.71              65621.74
# 4            66                 320        3306.82              48787.99
#
#    mcomisiones  ...  Visa_madelantodolares  Visa_fultimo_cierre  Visa_mpagado  \
# 0      1278.11  ...                    0.0                    4          0.00
# 1       418.97  ...                    0.0                   11      13267.49
# 2       174.26  ...                    0.0                    4          0.00
# 3     23590.68  ...                    0.0                   25      23800.17
# 4      3274.95  ...                    0.0                    4          0.00
#
#    Visa_mpagospesos  Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  \
# 0         -20833.47                 0.0            2814             6743.38
# 1          -9662.51                 0.0            5541             9419.90
# 2          -4692.00                 0.0             577             2821.32
# 3         -20349.22                 0.0            7916            23509.71
# 4         -88178.37                 0.0            1958            20397.54
#
#    Visa_cconsumos  Visa_cadelantosefectivo  Visa_mpagominimo
# 0               6                        0           9559.95
# 1               8                        0           1900.26
# 2               2                        0           6885.51
# 3               8                        0           1219.92
# 4               8                        0           2627.52
#
# [5 rows x 154 columns]

# %%
# %%sql
# SELECT
#     numero_de_cliente,
#     COUNT(*) AS cant_rep
# FROM competencia_01_crudo
# GROUP BY numero_de_cliente;
# Out:
#         numero_de_cliente  cant_rep
# 0               918170566         6
# 1               918183034         6
# 2               918186100         6
# 3               918238824         6
# 4               918250635         6
# ...                   ...       ...
# 168876         1596108649         1
# 168877         1596583543         1
# 168878         1596885756         1
# 168879         1596971444         1
# 168880         1598157023         1
#
# [168881 rows x 2 columns]

# %%
# %%sql
# select
#     foto_mes
#     , count(*) as cantidad -- cuenta cuantos casos hay en cada foto_mes
#                            -- y lo guarda en un campo llamado cantidad
# from competencia_01_crudo
# group by foto_mes
# Out:
#    foto_mes  cantidad
# 0    202101    161527
# 1    202102    162155
# 2    202103    163109
# 3    202104    163418
# 4    202105    163917
# 5    202106    164313

# %% [markdown]
# Perfecto, ahora cree una nueva tabla con la variable adicional que se le pide.

# %%
# %%sql
# -- DuckDB: clase_ternaria por continuidad mensual
# CREATE OR REPLACE MACRO clase_ternaria(t) AS TABLE (
# WITH base AS (
#   SELECT
#     *,
#     -- Índice mensual consecutivo: yyyymm → (yyyy * 12 + mm)
#     (CAST(foto_mes / 100 AS INTEGER) * 12 + (foto_mes % 100)) AS period_idx
#   FROM t
# ),
# seq AS (
#   SELECT
#     *,
#     LEAD(period_idx, 1) OVER (PARTITION BY numero_de_cliente ORDER BY period_idx) AS p1,
#     LEAD(period_idx, 2) OVER (PARTITION BY numero_de_cliente ORDER BY period_idx) AS p2
#   FROM base
# ),
# bounds AS (
#   SELECT MAX(period_idx) AS maxp FROM seq
# )
# SELECT
#   * EXCLUDE (period_idx, p1, p2),
#   CASE
#     -- BAJA+1: falta el mes siguiente (o no vuelve a aparecer)
#     WHEN period_idx < (SELECT maxp FROM bounds)
#          AND (p1 IS NULL OR p1 > period_idx + 1)
#     THEN 'BAJA+1'
#
#     -- BAJA+2: aparece el mes siguiente, pero falta el segundo siguiente
#     WHEN period_idx < (SELECT maxp FROM bounds) - 1
#          AND p1 = period_idx + 1
#          AND (p2 IS NULL OR p2 > period_idx + 2)
#     THEN 'BAJA+2'
#
#     -- CONTINUA: meses “antiguos” respecto del borde (al menos 2 meses antes del máximo)
#     WHEN period_idx <= (SELECT maxp FROM bounds) - 2
#     THEN 'CONTINUA'
#
#     -- Borde (último/anteúltimo mes global): no etiquetamos
#     ELSE NULL
#   END AS clase_ternaria
# FROM seq
# );
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# CREATE OR REPLACE VIEW t AS
# SELECT * FROM competencia_01_crudo;
#
# CREATE OR REPLACE TABLE competencia_01 AS
# SELECT * FROM clase_ternaria(t);
#
# DROP VIEW t;
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []

# %%
# %%sql
# -- Chequeo rápido de distribución
# SELECT foto_mes, clase_ternaria, COUNT(*) AS n
# FROM competencia_01
# GROUP BY 1,2
# ORDER BY 1,2;
# Out:
#     foto_mes clase_ternaria       n
# 0     202101         BAJA+1     622
# 1     202101         BAJA+2     825
# 2     202101       CONTINUA  160080
# 3     202102         BAJA+1     831
# 4     202102         BAJA+2    1032
# 5     202102       CONTINUA  160292
# 6     202103         BAJA+1    1039
# 7     202103         BAJA+2     951
# 8     202103       CONTINUA  161119
# 9     202104         BAJA+1     955
# 10    202104         BAJA+2    1130
# 11    202104       CONTINUA  161333
# 12    202105         BAJA+1    1134
# 13    202105           None  162783
# 14    202106           None  164313

# %%
# %sql select * from competencia_01 limit 5
# Out:
#    numero_de_cliente  foto_mes  active_quarter  cliente_vip  internet  \
# 0         1444378127    202101               1            0         0
# 1         1444378127    202102               1            0         0
# 2         1444378127    202103               1            0         0
# 3         1444378127    202104               1            0         0
# 4         1444378127    202105               1            0         0
#
#    cliente_edad  cliente_antiguedad  mrentabilidad  mrentabilidad_annual  \
# 0            29                  21       -5809.08              -2632.03
# 1            29                  22         333.49              -2691.60
# 2            29                  23        -786.35              -3257.35
# 3            30                  24         -36.40              -3908.41
# 4            30                  25        -426.91              -4719.10
#
#    mcomisiones  ...  Visa_fultimo_cierre  Visa_mpagado  Visa_mpagospesos  \
# 0       367.85  ...                    4           0.0         -37206.99
# 1       241.59  ...                   -3           0.0         -27835.39
# 2        96.29  ...                    1           0.0         -29762.86
# 3       434.17  ...                    2           0.0         -39697.28
# 4       420.05  ...                    5           0.0         -53211.60
#
#    Visa_mpagosdolares  Visa_fechaalta  Visa_mconsumototal  Visa_cconsumos  \
# 0                 0.0             364             3790.26               3
# 1                 0.0             392             1173.00               1
# 2                 0.0             423             6926.33               4
# 3                 0.0             453            19087.78               6
# 4                 0.0             484             6592.48               4
#
#    Visa_cadelantosefectivo  Visa_mpagominimo  clase_ternaria
# 0                        0           2815.20        CONTINUA
# 1                        0           2932.50        CONTINUA
# 2                        0           3190.56        CONTINUA
# 3                        0           4410.48        CONTINUA
# 4                        0            914.94            None
#
# [5 rows x 155 columns]

# %% [markdown]
# ## Ejercicio 1.1
# * ¿Cuál es la nominalidad de cada clase?

# %%
# %%sql
# PIVOT competencia_01
# on clase_ternaria
# USING count(numero_de_cliente)
# GROUP BY foto_mes
# Out:
#    foto_mes  BAJA+1  BAJA+2  CONTINUA
# 0    202101     622     825    160080
# 1    202102     831    1032    160292
# 2    202103    1039     951    161119
# 3    202104     955    1130    161333
# 4    202105    1134       0         0
# 5    202106       0       0         0

# %% [markdown]
# * ¿Cuál es la proporción del target?
#
# ## Guardar tabla en .csv
#
# Para guardar a un `.csv` simplemente debe ejecutar la siguiente sentencia

# %%
# %sql COPY competencia_01 TO '{{dataset_path}}competencia_01.csv' (FORMAT CSV, HEADER)
# Out:
# Empty DataFrame
# Columns: [Success]
# Index: []
